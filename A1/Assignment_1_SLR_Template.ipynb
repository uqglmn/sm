# %% [markdown]
# # Assignment 1 - Simple Linear Regression
#
# 5PAM1033 - Statistical Modelling
#
# Name Surname Student ID

# %% [markdown]
# ### 1. Simple Linear Regression Analysis

# %% [markdown]
# Fit a simple linear regression model to the given data:
#
# - Conduct residual analysis and find suitable transformations of data, if needed (2 marks).
#
# - Compute Cook's distances, find (and remove) outliers and bad leverage cases, if needed (2 marks).
#
# - Briefly explain the regression diagnostics you did and the transformations you made, if any, and evaluate the quality of your regression model (1 mark).
#
# You can use all built-in statistical functions (``lm()``, ``boxcox()``, ``rstandard()``, etc.) to complete this part.

# %% [markdown]
# ### 2. Analysis of Variance

# %% [markdown]
# Use formulas derived in lectures to:
#
# - Construct analysis of variance table (2 marks).
#
# - Test significance of regression (1 mark).
#
# All necessary quantities must be computed without using any built-in statistical function. Then use built-in statistical functions to verify your results.

# %%
# table formatting example

# replace numbers with your variables: SSR, SSE, etc.
table.anova = data.frame(row.names=c("Regression","Residual","Total"),
                         dof=c(0,0,0), 
                         SS=c(0,0,0),    
                         MS=c(0,0,NA),   
                         F=c(0,NA,NA)
                         )

# column names
names(table.anova) = c("d.o.f.", "SS", "MS", "F")

# round numerical values
round(table.anova,3)
# Out:
#            d.o.f. SS MS F
# Regression 0      0   0  0
# Residual   0      0   0 NA
# Total      0      0  NA NA

# %% [markdown]
# ### 3. Confidence and prediction

# %% [markdown]
# Produce a scatter plot of the data. Then draw the fitted regression line and
#
# - 95% confidence interval for the mean response (1 mark)
#
# - 95% prediction interval for new observations (1 mark)
#
# Your plot should look similar to the one below. All necessary quantities must be computed without using any built-in statistical function.
#
# <img align="left" width="350" height="350" src="https://github.com/uqglmn/sm/blob/3c5d0d8b6dec7951c88479937a5d5ff6f52eab3d/A1/cpi.png?raw=true">

# %%
# curve plotting example

x  = c(1:5)
y  = x^2 
y1 = y - 1
y2 = y + 1

options(repr.plot.width=5, repr.plot.height=5) 
plot(x, y)
lines(x, y,  col=3)
lines(x, y1, col=2)
lines(x, y2, col=2)
# Out:
# plot without title

# %% [markdown]
# ### Memo

# %% [markdown]
# - 10% of  marks are allocated for presentation quality of your work.
# - Don't forget to verify your work. Restart the kernel and re-run the whole notebook.
# - Make a pdf copy of this notebook and submit together with the notebook.

# %% [markdown]
# ---
