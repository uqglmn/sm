# %% [markdown]
# ## Tutorial Sheet 7
#
# **Multiple Linear Regression**
#
# Hypothesis Testing

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 1
#
# Can Southern California's water supply in future years be predicted from past data? One factor affecting water availability is stream runoff. If runoff could be predicted, engineers, planners, and policy makers could do their jobs more efficiently. The data file contains 43 years’ worth of precipitation measurements taken at six sites in the Sierra Nevada mountains (labelled APMAM, APSAB, APSLAKE, OPBPC, OPRC, and OPSLAKE) and stream runoff volume at a site near Bishop, California, labelled BSAAM.

# %% [markdown]
# ***

# %% [markdown]
# **1.1.** Read and visually inspect the data.

# %%
water = read.csv("https://raw.githubusercontent.com/uqglmn/sm/main/water.csv")
str(water)
# Out:
# 'data.frame':	43 obs. of  8 variables:
#  $ Year   : int  1948 1949 1950 1951 1952 1953 1954 1955 1956 1957 ...
#  $ APMAM  : num  9.13 5.28 4.2 4.6 7.15 9.7 5.02 6.7 10.5 9.1 ...
#  $ APSAB  : num  3.58 4.82 3.77 4.46 4.99 5.65 1.45 7.44 5.85 6.13 ...
#  $ APSLAKE: num  3.91 5.2 3.67 3.93 4.88 4.91 1.77 6.51 3.38 4.08 ...
#  $ OPBPC  : num  4.1 7.55 9.52 11.14 16.34 ...
#  $ OPRC   : num  7.43 11.11 12.2 15.15 20.05 ...
#  $ OPSLAKE: num  6.47 10.26 11.35 11.13 22.81 ...
#  $ BSAAM  : int  54235 67567 66161 68094 107080 67594 65356 67909 92715 70024 ...

# %%
panel.cor = function(x, y, ...)
{
  par(usr = c(0, 1, 0, 1))
  txt = as.character(format(cor(x, y), digits=2))
  text(0.5, 0.5, txt, cex=1.5)
}

# %%
options(repr.plot.width=9, repr.plot.height=9)

pairs(BSAAM~APMAM+APSAB+APSLAKE+OPBPC+OPRC+OPSLAKE, data=water,
      lower.panel=panel.cor, 
      cex.labels=1.5, cex.axis=1.5)
# Out:
# plot without title

# %% [markdown]
# _ _ _

# %% [markdown]
# **1.2.** Construct the design matrix X for the model ``BSAAM ~ APMAM + APSAB + APSLAKE + OPBPC + OPRC + OPSLAKE`` and find estimated values of the corresponding regression parameters. Then verify your results using the built-in statistical functions.

# %%
# write your code here

# %% [markdown]
# _ _ _

# %% [markdown]
# **1.3.** Test the overall significance of regression assuming $\alpha = 5\%$ and find $R^2$ and $R^2_{adj}$.

# %%
# write your code here

# %% [markdown]
# _ _ _

# %% [markdown]
# **1.4.** Conduct individual $t$-tests for significance of individual regression coefficients.

# %%
# write your code here

# %% [markdown]
# _ _ _

# %% [markdown]
# **1.5.** Identitfy a group of least significant predictors and conduct a partial $F$-test to test significance of this group.

# %%
# write your code here

# %% [markdown]
# _ _ _

# %% [markdown]
# **1.6.** Test the overall significance of regression assuming $\alpha = 5\%$ and find the adjusted coefficient of determination, $R^2_{adj}$ of the reduced model.

# %%
# write your code here

# %% [markdown]
# _ _ _

# %% [markdown]
# **1.7.** Compare the overall significance of regression, the $\hat\sigma^2$ and the $R^2_{adj}$ of the full and the reduced models.

# %%
# write your code here

# %% [markdown]
# _ _ _

# %% [markdown]
# ### Exercise 2
#
# The file [https://raw.githubusercontent.com/uqglmn/sm/main/gpa.csv](https://raw.githubusercontent.com/uqglmn/sm/main/gpa.csv) contains sample of 219 records from a larger set of data collected in 1996 at Midwestern College, U.S. It contains 7 variables:
#
# - ``GPA`` - first-year college GPA on a 0.0-4.0 scale
# - ``HSGPA`` - high school GPA on a 0.0-4.0 scale
# - ``SATV`` - cerbal/critical reading SAT score
# - ``SATM`` - mathematics SAT score
# - ``Sex`` - a dummy variable: 1= male, 0= female
# - ``HU`` - the number of credit hours earned in humanities courses in high school
# - ``SS`` - the number of credit hours earned in social science courses in high school
#
# Using this data construct a parsimonious multiple linear regression model for predicting the first-year college GPA record in terms of the remaining variables.
#
# Follow the steps in Exercise 1.

# %%
# write your code here

# %% [markdown]
# _ _ _

# %% [markdown]
# ### Exercise 3
#
# Chateau Latour is widely acknowledged as one of the world's greatest wine estates with a rich history dating back to at least 1638. The Grand Vin de Chateau Latour is a wine of incredible power and longevity. Quality of a particular vintage of Chateau Latour has a huge impact on price. For example, in March 2007, the 1997 vintage of Chateau Latour could be purchased for as little as \\$159 per bottle while the 2000 vintage of Chateau Latour costs as least \\$700 per bottle (www.wine-searcher.com).
#
# While many studies have identified that the timing of the harvest of the grapes has an important effect on the quality of the vintage, with quality improving the earlier the harvest. A less explored issue of interest is the effect of unwanted rain at vintage time on the quality of icon wine like Chateau Latour. This exercise addresses this issue.
#
# The Chateau Latour web site (www.chateau-latour.com) provides a rich source of data. In particular, data on the quality of each vintage, harvest dates and weather at harvest time were obtained from the site for the vintages from 1961 to 2004. An example of the information on weather at harvest time is given below for the 1994 vintage:
#
# *Harvest began on the 13th September and lasted on the 29th, frequently interrupted by storm showers. But quite amazingly the dilution effect in the grapes was very limited*
#
# Each vintage was classified as having had “unwanted rain at harvest” (e.g., the 1994 vintage) or not (e.g., the 1996 vintage) on the basis of information like that reproduced above. Thus, the data consist of:
#
# - ``Vintage`` = year the grapes were harvested Quality – on a scale from 1 (worst) to 5 (best) with some half points
# - ``End of harvest`` – measured as the number days since August 31
# - ``Rain`` – a dummy variable for unwanted rain at harvest = 1 if yes.
#
# The data is give in [https://raw.githubusercontent.com/uqglmn/sm/main/mlr/latour.csv](https://raw.githubusercontent.com/uqglmn/sm/main/mlr/latour.csv).

# %% [markdown]
# - - -

# %% [markdown]
# **3.1.** Show that the coefficient of the interaction term in model ``Quality ~ Run * EndofHarvest`` is statistically significant. In other words, show that the rate of change in quality rating depends on whether there has been any unwanted rain at vintage.

# %%
latour = read.csv("https://raw.githubusercontent.com/uqglmn/sm/main/mlr/latour.csv")
str(latour)
# Out:
# 'data.frame':	44 obs. of  4 variables:
#  $ Vintage     : int  1961 1962 1963 1964 1965 1966 1967 1968 1969 1970 ...
#  $ Quality     : num  5 4 1 3 1 4 3 2 2 4 ...
#  $ EndofHarvest: int  28 50 53 38 46 40 35 38 45 47 ...
#  $ Rain        : int  0 0 1 0 1 0 1 1 1 0 ...

# %%
options(repr.plot.width=3, repr.plot.height=3)
par(mfrow=c(1,1), mar=c(4,4,2,1))

plot(Quality~EndofHarvest, col=as.factor(Rain), data=latour, 
     cex.main=1, cex.axis=1, font.main = 1, cex.lab = 1, main="Wine Quality")
# Out:
# Plot with title “Wine Quality”

# %% [markdown]
# **Hint:** The model you need to fit has three preditors: ``Rain``, ``EndofHarvest``, and the interaction term ``Rain:EndofHarvest``. This must be reflected in the design matrix.

# %%
# write your code here

# %% [markdown]
# - - -

# %% [markdown]
# **3.2.** Estimate the number of days of delay to the end of harvest it takes to decrease the quality rating by 1 point when there is:
# - No unwanted rain at harvest
# - Some unwanted rain at harvest
#
# **Hint:** This question can be done by hand. Simply write down the fitted regression model
#
# $$
# \texttt{Quality} = \hat\beta_0 + \hat\beta_1 \texttt{Rain} + \hat\beta_2 \texttt{EndofHarvest} + \hat\beta_{12} \texttt{Rain} \times \texttt{EndofHarvest}
# $$
#
# and find the difference of ``EndofHarvest`` that decreses ``Quality`` by 1 unit when ``Rain``=0 and when ``Rain``=1.

# %%
# write your code here

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 4
#
# Show that the vector of residuals in a linear regression model can be written as
#
# $$
# \vec e = (I - H)\, \vec\varepsilon
# $$
#
# This exercise should be done by hand.

# %% [markdown]
# ---
